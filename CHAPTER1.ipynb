# %% [markdown]
# <a href="https://colab.research.google.com/github/pigi0420/AIandMLForCodersBook/blob/main/CHAPTER1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1장 TensorFlow 소개**

# %% [markdown]
# TensorFlow 버전 확인

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# TensorFlow 버전 설정
# > python3.9 버전으로 pip 혹은 conda로 라이브러리들을 설치하면 에러와 함께 버전 다운이 불가능

# %%
#!pip install tensorflow==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.1.0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0)
# ERROR: No matching distribution found for tensorflow==2.1.0

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 텐서플로 케라스 API를 이용한 전체 코드

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 457ms/step - loss: 27.0634
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 21.5920
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 17.2811
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 13.8836
# Epoch 5/500
# 1/1 [==============================] - 0s 17ms/step - loss: 11.2046
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0912
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.4227
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1045
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0620
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2365
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.5818
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0616
# ...
